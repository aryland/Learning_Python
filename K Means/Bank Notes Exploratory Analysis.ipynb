# %%
pwd
# Out:
# 'C:\\Users\\Austin'

# %%
import pandas as pd

data = pd.read_csv('Bank Notes.csv')

print(data)
# Out:
#            V1        V2
# 0     3.62160   8.66610
# 1     4.54590   8.16740
# 2     3.86600  -2.63830
# 3     3.45660   9.52280
# 4     0.32924  -4.45520
# ...       ...       ...
# 1367  0.40614   1.34920
# 1368 -1.38870  -4.87730
# 1369 -3.75030 -13.45860
# 1370 -3.56370  -8.38270
# 1371 -2.54190  -0.65804
#
# [1372 rows x 2 columns]

# %%
import pandas as pd

data = pd.read_csv('Bank Notes.csv')

Version1 = data['V1']
Version2 = data['V2']

print(Version2)
# Out:
# 0        8.66610
# 1        8.16740
# 2       -2.63830
# 3        9.52280
# 4       -4.45520
#           ...
# 1367     1.34920
# 1368    -4.87730
# 1369   -13.45860
# 1370    -8.38270
# 1371    -0.65804
# Name: V2, Length: 1372, dtype: float64

# %%
min(Version1)
# Out:
# -7.0421

# %%
max(Version1)
# Out:
# 6.8248

# %%
sum(Version1)
# Out:
# 595.084773

# %%
sum(Version2)
# Out:
# 2637.4684820000025

# %%
min(Version2)
# Out:
# -13.7731

# %%
max(Version2)
# Out:
# 12.9516

# %% [markdown]
# data.sort_values('Version', inplace=True)

# %%
import pandas as pd

data = pd.read_csv('Bank Notes.csv')

Version1 = data['V1']
Version2 = data['V2']

data.sort_values('V1', inplace=True)


import matplotlib.pyplot as plt

plt.xlabel('Version1')
plt.ylabel('Version2')
plt.scatter(Version1, Version2, alpha = .15)

# %% [markdown]
# Version1_mean = np.mean(data['V1'])
# Version2_mean = np.mean(data['V2'])
#
#
# print(Version1_mean, Version2_mean)

# %%
import numpy as np

data.sort_values('V1', inplace=True)

Version1_mean = np.mean(data['V1'])
Version2_mean = np.mean(data['V2'])

Version1_stdv = np.std(data['V1'])
Version2_stdv = np.std(data['V2'])

print(Version1_mean, Version2_mean)
# Out:
# 0.43373525728862916 1.9223531209912554

# %%
import numpy as np

data.sort_values('V1', inplace=True)

Version1_stdv = np.std(data['V1'])
Version2_stdv = np.std(data['V2'])

print(Version1_stdv, Version2_stdv)
# Out:
# 2.841726405206094 5.8669074882719965

# %%
import pandas as pd

data = pd.read_csv('Bank Notes.csv')

Version1 = data['V1']
Version2 = data['V2']

data.sort_values('V1', inplace=True)


import matplotlib.pyplot as plt

plt.xlabel('Version1')
plt.ylabel('Version2')
plt.scatter(Version1, Version2, alpha = .15)

# %%
from sklearn.cluster import KMeans
import numpy as np

Version1_Version2 = np.column_stack((Version1, Version2))
print(Version1_Version2)
# Out:
# [[  3.6216    8.6661 ]
#  [  4.5459    8.1674 ]
#  [  3.866    -2.6383 ]
#  ...
#  [ -3.7503  -13.4586 ]
#  [ -3.5637   -8.3827 ]
#  [ -2.5419   -0.65804]]

# %%
data.sort_values('V1', inplace=True)

data
# Out:
#           V1      V2
# 1233 -7.0421  9.2000
# 1294 -7.0364  9.2931
# 1172 -6.9599  8.9931
# 989  -6.7526  8.8172
# 1203 -6.7387  6.9879
# ...      ...     ...
# 199   5.8862  5.8747
# 513   5.9374  6.1664
# 215   6.0919  2.9673
# 28    6.5633  9.8187
# 634   6.8248  5.2187
#
# [1372 rows x 2 columns]

# %%
from sklearn.cluster import KMeans
import numpy as np

Version1_Version2 = np.column_stack((Version1, Version2))

km_res = KMeans(n_clusters=4).fit(Version1_Version2)

clusters = km_res.cluster_centers_

plt.scatter(Version1, Version2)
plt.scatter(clusters[:,0], clusters[:,1], s=1000)


import matplotlib.pyplot as plt

plt.xlabel('Version1')
plt.ylabel('Version2')
# Out:
# Text(0, 0.5, 'Version2')

# %%
data
# Out:
#           V1      V2
# 1233 -7.0421  9.2000
# 1294 -7.0364  9.2931
# 1172 -6.9599  8.9931
# 989  -6.7526  8.8172
# 1203 -6.7387  6.9879
# ...      ...     ...
# 199   5.8862  5.8747
# 513   5.9374  6.1664
# 215   6.0919  2.9673
# 28    6.5633  9.8187
# 634   6.8248  5.2187
#
# [1372 rows x 2 columns]

# %%
from sklearn.cluster import KMeans
import numpy as np

Version1_Version2 = np.column_stack((Version1, Version2))
#print(Version1_Version2)

x_min = np.min(Version1_Version2[:,0])
x_max = np.max(Version1_Version2[:,-1])
print(x_min, x_max)
# Out:
# -7.0421 12.9516

# %%
from sklearn.cluster import KMeans
import numpy as np

Version1_Version2 = np.column_stack((Version1, Version2))
#print(Version1_Version2)

x_min = np.min(Version1_Version2[:,0])
x_max = np.max(Version1_Version2[:,-1])
#print(x_min, x_max)

normed_x = (Version1_Version2[:,0] - x_min) / (x_max - x_min)
print(normed_x)
# Out:
# [0.53335301 0.57958257 0.54557686 ... 0.16464186 0.1739748  0.2250809 ]

# %%
import pandas as pd

data = pd.read_csv('Bank Notes.csv')

Version1 = data['V1']
Version2 = data['V2']

data.sort_values('V1', inplace=True)

import matplotlib.pyplot as plt

plt.xlabel('Version1')
plt.ylabel('Version2')
plt.scatter(Version1, Version2, alpha = .15)


from sklearn.cluster import KMeans
import numpy as np

Version1_Version2 = np.column_stack((Version1, Version2))
#print(Version1_Version2)

x_min = np.min(Version1_Version2[:,0])
x_max = np.max(Version1_Version2[:,-1])
#print(x_min, x_max)

normed_x = (Version1_Version2[:,0] - x_min) / (x_max - x_min)
#print(normed_x)

# %%
normed_x
# Out:
# array([0.53335301, 0.57958257, 0.54557686, ..., 0.16464186, 0.1739748 ,
#        0.2250809 ])

# %%
import pandas as pd

data = pd.read_csv('Bank Notes.csv')

Version1 = data['V1']
Version2 = data['V2']

All_Versions = (Version1, Version2)
print(All_Versions)
# Out:
# (0       3.62160
# 1       4.54590
# 2       3.86600
# 3       3.45660
# 4       0.32924
#          ...
# 1367    0.40614
# 1368   -1.38870
# 1369   -3.75030
# 1370   -3.56370
# 1371   -2.54190
# Name: V1, Length: 1372, dtype: float64, 0        8.66610
# 1        8.16740
# 2       -2.63830
# 3        9.52280
# 4       -4.45520
#           ...
# 1367     1.34920
# 1368    -4.87730
# 1369   -13.45860
# 1370    -8.38270
# 1371    -0.65804
# Name: V2, Length: 1372, dtype: float64)

# %%
import pandas as pd

data = pd.read_csv('Bank Notes.csv')

Version1 = data['V1']
Version2 = data['V2']

data.sort_values('V1', inplace=True)

import matplotlib.pyplot as plt
import seaborn as sea

plt.xlabel('Version1')
plt.ylabel('Version2')
plt.scatter(Version1, Version2, alpha = .15)

# %%
from sklearn.cluster import KMeans
import numpy as np

Version1_Version2 = np.column_stack((Version1, Version2))

km_res = KMeans(n_clusters=4).fit(Version1_Version2)

clusters = km_res.cluster_centers_

plt.scatter(Version1, Version2, alpha = .15)
plt.scatter(clusters[:,0], clusters[:,1], s=1000)


import matplotlib.pyplot as plt

plt.xlabel('Version1')
plt.ylabel('Version2')
# Out:
# Text(0, 0.5, 'Version2')

# %%
from sklearn.cluster import KMeans
import numpy as np

Version1_Version2 = np.column_stack((Version1, Version2))

km_res = KMeans(n_clusters=3).fit(Version1_Version2)

clusters = km_res.cluster_centers_

plt.scatter(Version1, Version2, alpha = .15)
plt.scatter(clusters[:,0], clusters[:,1], s=1000)


import matplotlib.pyplot as plt

plt.xlabel('Version1')
plt.ylabel('Version2')
# Out:
# Text(0, 0.5, 'Version2')

# %%
from sklearn.cluster import KMeans
import numpy as np

Version1_Version2 = np.column_stack((Version1, Version2))

km_res = KMeans(n_clusters=2).fit(Version1_Version2)

clusters = km_res.cluster_centers_

plt.scatter(Version1, Version2, alpha = .15)
plt.scatter(clusters[:,0], clusters[:,1], s=1000)

#res=KMeans(n_clusters=2,max_iter=243).fit(np.column_stack((x,y)))

import matplotlib.pyplot as plt

plt.xlabel('Version1')
plt.ylabel('Version2')



x_min = np.min(Version1_Version2[:,0])
x_max = np.max(Version1_Version2[:,-1])
#print(x_min, x_max)

normed_x = (Version1_Version2[:,0] - x_min) / (x_max - x_min)
# Out:
# Text(0, 0.5, 'Version2')

# %%
import pandas as pd
import numpy as np

data = pd.read_csv('Bank Notes.csv')

Version1 = data['V1']
Version2 = data['V2']

data.sort_values('V1', inplace=True)

#Version1_Version2 = np.column_stack((Version1, Version2))

Version1_min = np.min(Version1[:,0])
Version1_max = np.max(Version1[:,-1])
Version2_min = np.min(Version2[:,0])
Version2_max = np.max(Version2[:,-1])

normed_Version1 = (Version1[:,0] - x_min) / (x_max - x_min)
normed_Version2 = (Version2[:,0] - y_min) / (y_max - y_min)

print(normed_Version1, normed_Version2)

All_Versions = np.column_stack((normed_x, normed_y))

from sklearn.cluster import KMeans
import numpy as np


km_res = KMeans(n_clusters=2).fit(All_Versions)

clusters = km_res.cluster_centers_

plt.scatter(normed_x, alpha = .15)
plt.scatter(clusters[:,0], clusters[:,1], s=1000)

#res=KMeans(n_clusters=2,max_iter=243).fit(np.column_stack((x,y)))

import matplotlib.pyplot as plt

plt.xlabel('Version1')
plt.ylabel('Version2')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-fce98b78c824> in <module>
#      10 #Version1_Version2 = np.column_stack((Version1, Version2))
#      11
# ---> 12 Version1_min = np.min(Version1[:,0])
#      13 Version1_max = np.max(Version1[:,-1])
#      14 Version2_min = np.min(Version2[:,0])
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     908             key = check_bool_indexer(self.index, key)
#     909
# --> 910         return self._get_with(key)
#     911
#     912     def _get_with(self, key):
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _get_with(self, key)
#     921         elif isinstance(key, tuple):
#     922             try:
# --> 923                 return self._get_values_tuple(key)
#     924             except ValueError:
# ...

# %%
import pandas as pd

data = pd.read_csv('Bank Notes.csv')

Version1 = data['V1']
Version2 = data['V2']

data.sort_values('V1', inplace=True)

All_Versions = np.column_stack((Version1, Version2))

All_Versions_min = np.min(data,0)
All_Versions_max = np.max(data,0)
All_Versions_normed = (data - All_Versions_min) / (All_Versions_max - All_Versions_min)

print(All_Versions_normed)
# Out:
#             V1        V2
# 1233  0.000000  0.859621
# 1294  0.000411  0.863104
# 1172  0.005928  0.851879
# 989   0.020877  0.845297
# 1203  0.021879  0.776847
# ...        ...       ...
# 199   0.932314  0.735193
# 513   0.936006  0.746108
# 215   0.947148  0.626402
# 28    0.981142  0.882771
# 634   1.000000  0.710646
#
# [1372 rows x 2 columns]

# %%
import pandas as pd
import numpy as np

data = pd.read_csv('Bank Notes.csv')

Version1 = data['V1']
Version2 = data['V2']

data.sort_values('V1', inplace=True)

All_Versions = np.column_stack((Version1, Version2))

V1_min = np.min(All_Versions[:,0])
V1_max = np.max(All_Versions[:,0])
V1_normed = (All_Versions[:,0] - V1_min) / (V1_max - V1_min)


V2_min = np.min(All_Versions[:,1])
V2_max = np.max(All_Versions[:,1])
V2_normed = (All_Versions[:,1] - V2_min) / (V2_max - V2_min)


print(V1_normed, V2_normed)


All_Versions = np.column_stack((V1_normed, V2_normed))

All_Versions_min = np.min(data,0)
All_Versions_max = np.max(data,0)
All_Versions_normed = (data - All_Versions_min) / (All_Versions_max - All_Versions_min)

print(All_Versions_normed)
# Out:
# [0.76900389 0.83565902 0.78662859 ... 0.23738543 0.25084193 0.32452819] [0.83964273 0.82098209 0.41664827 ... 0.01176814 0.20170105 0.49074676]
#             V1        V2
# 1233  0.000000  0.859621
# 1294  0.000411  0.863104
# 1172  0.005928  0.851879
# 989   0.020877  0.845297
# 1203  0.021879  0.776847
# ...        ...       ...
# 199   0.932314  0.735193
# 513   0.936006  0.746108
# 215   0.947148  0.626402
# 28    0.981142  0.882771
# 634   1.000000  0.710646
#
# [1372 rows x 2 columns]

# %%
from sklearn.cluster import KMeans
import numpy as np
import matplotlib.pyplot as plt

#All_Versions = np.column_stack((V1_normed, V2_normed))

km_res = KMeans(n_clusters=2).fit(All_Versions_normed)

clusters = km_res.cluster_centers_

plt.scatter(V1_normed, V2_normed, color = 'turquoise', alpha = .15)
plt.scatter(clusters[:,0], clusters[:,1], s=1000, color = 'gold')


import matplotlib.pyplot as plt

plt.xlabel('Version1 Normalized')
plt.ylabel('Version2 Normalized')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-ad31a3c5d004> in <module>
#       5 #All_Versions = np.column_stack((V1_normed, V2_normed))
#       6
# ----> 7 km_res = KMeans(n_clusters=2).fit(All_Versions_normed)
#       8
#       9 clusters = km_res.cluster_centers_
#
# NameError: name 'All_Versions_normed' is not defined

# %%
# Out:
#   File "<ipython-input-1-a7c30f5ba183>", line 1
#     plt.savefig(‘fig1’)
#                      ^
# SyntaxError: invalid character in identifier

# %%
import pandas as pd
import numpy as np

data = pd.read_csv('Bank Notes.csv')

Version1 = data['V1']
Version2 = data['V2']

data.sort_values('V1', inplace=True)

All_Versions = np.column_stack((Version1, Version2))

V1_min = np.min(All_Versions[:,0])
V1_max = np.max(All_Versions[:,0])
V1_normed = (All_Versions[:,0] - V1_min) / (V1_max - V1_min)


V2_min = np.min(All_Versions[:,1])
V2_max = np.max(All_Versions[:,1])
V2_normed = (All_Versions[:,1] - V2_min) / (V2_max - V2_min)


print(V1_normed, V2_normed)


All_Versions = np.column_stack((V1_normed, V2_normed))

All_Versions_min = np.min(data,0)
All_Versions_max = np.max(data,0)
All_Versions_normed = (data - All_Versions_min) / (All_Versions_max - All_Versions_min)


from sklearn.cluster import KMeans
import numpy as np
import matplotlib.pyplot as plt

#All_Versions = np.column_stack((V1_normed, V2_normed))

km_res = KMeans(n_clusters=2).fit(All_Versions_normed)

clusters = km_res.cluster_centers_

plt.scatter(V1_normed, V2_normed, color = 'turquoise', alpha = .15)
plt.scatter(clusters[:,0], clusters[:,1], s=1000, color = 'gold')


import matplotlib.pyplot as plt

plt.xlabel('Version1 Normalized')
plt.ylabel('Version2 Normalized')
# Out:
# [0.76900389 0.83565902 0.78662859 ... 0.23738543 0.25084193 0.32452819] [0.83964273 0.82098209 0.41664827 ... 0.01176814 0.20170105 0.49074676]
# Text(0, 0.5, 'Version2 Normalized')

# %%
import pandas as pd
import numpy as np

data = pd.read_csv('Bank Notes.csv')

Version1 = data['V1']
Version2 = data['V2']

data.sort_values('V1', inplace=True)

All_Versions = np.column_stack((Version1, Version2))

V1_min = np.min(All_Versions[:,0])
V1_max = np.max(All_Versions[:,0])
V1_normed = (All_Versions[:,0] - V1_min) / (V1_max - V1_min)


V2_min = np.min(All_Versions[:,1])
V2_max = np.max(All_Versions[:,1])
V2_normed = (All_Versions[:,1] - V2_min) / (V2_max - V2_min)


print(V1_normed, V2_normed)


All_Versions = np.column_stack((V1_normed, V2_normed))

All_Versions_min = np.min(data,0)
All_Versions_max = np.max(data,0)
All_Versions_normed = (data - All_Versions_min) / (All_Versions_max - All_Versions_min)


from sklearn.cluster import KMeans
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#All_Versions = np.column_stack((V1_normed, V2_normed))

km_res = KMeans(n_clusters=2).fit(All_Versions_normed)

clusters = km_res.cluster_centers_

sns.scatterplot(V1_normed,V2_normed, alpha = .15)
plt.scatter(clusters[:,0], clusters[:,1], s=1000, color = 'gold', alpha = .75)


import matplotlib.pyplot as plt

plt.xlabel('Version1 Normalized')
plt.ylabel('Version2 Normalized')
# Out:
# [0.76900389 0.83565902 0.78662859 ... 0.23738543 0.25084193 0.32452819] [0.83964273 0.82098209 0.41664827 ... 0.01176814 0.20170105 0.49074676]
# Text(0, 0.5, 'Version2 Normalized')

# %%
clusters = km_res.cluster_centers_

# %%
km_res.cluster_centers_
# Out:
# array([[0.36955897, 0.44781178],
#        [0.67364922, 0.69798136]])
